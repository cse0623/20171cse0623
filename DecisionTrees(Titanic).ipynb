# %% [markdown]
# <a href="https://colab.research.google.com/github/cse0623/20171CSE0623/blob/colab/DecisionTrees(Titanic).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("caTools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘bitops’

# %%
install.packages("dplyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("party")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘TH.data’, ‘libcoin’, ‘matrixStats’, ‘multcomp’, ‘mvtnorm’, ‘modeltools’, ‘strucchange’, ‘coin’, ‘zoo’, ‘sandwich’

# %%
install.packages("partykit")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Formula’, ‘inum’

# %%
install.packages("rpart.plot")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#Author DataFlair
library(rpart)
library(readr)
library(caTools)
library(dplyr)
library(party)
library(partykit)
library(rpart.plot)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: grid
#
# Loading required package: mvtnorm
#
# Loading required package: modeltools
#
# Loading required package: stats4
#
# Loading required package: strucchange
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: sandwich
#
# Loading required package: libcoin
#
#
# Attaching package: ‘partykit’
#
#
# The following objects are masked from ‘package:party’:
#
#     cforest, ctree, ctree_control, edge_simple, mob, mob_control,
#     node_barplot, node_bivplot, node_boxplot, node_inner, node_surv,
#     node_terminal, varimp

# %%
titanic_data <- "https://goo.gl/At238b" %>%  #DataFlair
  read.csv %>% # read in the data
  select(survived, embarked, sex, 
         sibsp, parch, fare) %>%
  mutate(embarked = factor(embarked),
         sex = factor(sex))

# %%
set.seed(123)
sample_data = sample.split(titanic_data, SplitRatio = 0.75)
train_data <- subset(titanic_data, sample_data == TRUE)
test_data <- subset(titanic_data, sample_data == FALSE)

# %%
head(train_data)
# Out:
#   survived embarked sex    sibsp parch fare
# 1 1        S        female 0     0     211.3375
# 2 1        S        male   1     2     151.5500
# 3 0        S        female 1     2     151.5500
# 6 1        S        male   0     0      26.5500
# 7 1        S        female 1     0      77.9583
# 8 0        S        male   0     0       0.0000

# %%
rtree <- rpart(survived ~ ., train_data)
rpart.plot(rtree)
# Out:
# plot without title

# %%
ctree_ <- ctree(survived ~ ., train_data)
plot(ctree_)
# Out:
# plot without title
